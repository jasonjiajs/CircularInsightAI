# %%
from openai import OpenAI
import pandas as pd
import numpy as np
import os
import json

# %% [markdown]
# # Preprocess df

# %%
# Preprocess df
df = pd.read_csv('../data/test_data_labeled.csv')[['problem', 'solution', 'relevance_problem', 'clarity_problem', 'suitability_solution', 'clarity_solution']]
df
# Out:
#                                               problem  \
# 0                             Plastic waste pollution
# 1   The problem that the solution of composting wa...
# 2   The solution can solve rising problems of poll...
# 3   Project Shrimati, an initiative by students of...
# 4   The fashion industry is notably one of the mos...
# 5   The high energy consumption and environmental ...
# 6   The production and disposal of single-use prod...
# 7          Green house emissions, depleting resources
# 8   Every year, the fashion industry produces bill...
# 9   The global textile industry is a significant c...
# 10  Current modes of product packaging contribute ...
# 11                                PLASTIC RECYCLING\n
# 12                                          Transport
# 13  Substantial waste generated from the productio...
# 14  Currently, a significant amount of obsolete el...
# 15  The fast fashion industry contributes signific...
# 16  One of the major issues our consumer-focused s...
# 17  Inaccessibility of high-value items for some p...
# 18  There is a significant amount of e-waste gener...
# 19  The traditional construction method has a huge...
# 20  Transforms carbon dioxide into high-protein an...
# 21  Overproduction and waste in the fast fashion s...
# 22  The problem that this idea is meant to address...
# 23  Rapid and unchecked urbanization has escalated...
# 24  Waste management is a significant global probl...
# 25  Our current linear economy model promotes a 'u...
# 26                            Paper Bags with Handles
# 27  We are facing a severe pollution and waste cri...
# 28  The significant waste produced by the disposal...
# 29          Plastic waste cause by the used packaging
# 30  The fashion industry is one of the largest con...
# 31  disposal of lithium-ion batteries in landfilli...
# 32  One of the issues our consumer-led society fac...
# 33  No problem, cuz recycling itself makes another...
# 34  Increasing levels of CO2 and other greenhouse ...
# 35  Helping people in developing countries to sell...
# 36  In our fast-paced world, every year billions o...
# 37  Single-use plastic packaging remains a signifi...
# 38  There is waste from marble factories in an are...
# 39  The excessive use of single-use plastic, glass...
# 40  The colossal waste produced by the fashion ind...
# 41  The problem this solution is meant to solve is...
# 42  The fashion industry is one of the most pollut...
# 43  The existing modes of intercontinental shippin...
# 44  The fashion industry is the second largest pol...
# 45  - Each year in the US more than four billion p...
# 46  Rising levels of carbon dioxide emissions and ...
# 47  This solution is meant to solve to problem of ...
# 48  With the increasing prevalence of autonomous v...
# 49  The current use of single-use plastic for pack...
#
#                                              solution  relevance_problem  \
# 0   recycling single-use plastic waste and convert...                  3
# 1   I worked on a project that collected waste veg...                  3
# 2   A circular economy takes a step forward from t...                  1
# 3   Our objective with Project Shrimati is to tack...                  3
# 4   I propose a 'Fashion Rental and Resell' model ...                  3
# 5   My proposal is to implement a ""Closed-Loop Ma...                  3
# 6   A rent, return, and refill model for product p...                  3
# 7   Food waste is a major contributor to greenhous...                  2
# 8     We propose a solution in the form of a decen...                  3
# 9    My solution is a double-pronged approach of '...                  3
# 10  I propose a scalable ""Packaging as a Service"...                  3
# 11                 PLASTIC PRODUCTS RECYCLING PROCESS                  2
# 12                                        clean world                  1
# 13  We propose a 'Hybrid Fashion Platform' that bl...                  3
# 14  My proposal is a ""Smart E-Waste Management & ...                  3
# 15  Introducing a 'Fashion Recycling Ecosystem (FR...                  3
# 16  I propose an eco-friendly business model, ""Pr...                  3
# 17  One potential circular economy idea is the cre...                  1
# 18  Let's develop a wide-scale, accessible solutio...                  3
# 19  A unique and novel bio-based materials and bio...                  2
# 20  Using microbes to re-imagine using CO2 emissio...                  2
# 21  Develop a Hybrid Clothing Marketplace that inc...                  3
# 22  The idea is to reduce the waste generated in t...                  3
# 23  I propose a concept I call ""E-Cycle,"" a syst...                  3
# 24  The proposal lies in creating a robust 'E-Wast...                  3
# 25  Develop a comprehensive ""Product Life Extensi...                  3
# 26  Well, in many places in Canada plastic bags ar...                  1
# 27  My proposal is 'Returnable Delivery Packages' ...                  3
# 28  Instead of discarding non-functioning light bu...                  3
# 29  An app that manage the reverse logistics of th...                  3
# 30  The concept of 'Fashion as a Service' can miti...                  3
# 31  tesla recycles old lithium-ion batteries by co...                  2
# 32  The concept of E-Waste Recycling Kiosks could ...                  3
# 33  ProductÐasÐaÐservice, Renewability, Sharing pl...                  1
# 34  We propose an innovative and cost-efficient ex...                  1
# 35  Soles4Souls helps people in developing countri...                  1
# 36  My solution proposal is an ""Electronics Leasi...                  3
# 37  My solution proposes a packaging-as-a-service ...                  3
# 38  There are extension areas where we can put rec...                  2
# 39  I propose a shift to a centralized, reusable c...                  3
# 40  The proposed solution is a platform that enabl...                  3
# 41  The solution involves creating an online platf...                  3
# 42  ""Full Turn Fashion"" is a circular economy co...                  3
# 43  The proposed solution is a maglev (magnetic le...                  1
# 44  My proposed solution is a clothing rental or l...                  2
# 45  Interface Inc. is a global flooring manufactur...                  3
# 46  Bio-engineered oil production using carbon dio...                  1
# 47  As many people return to work and their daily ...                  3
# 48  Deployment of a universal, non-invasive system...                  2
# 49  A solution to this problem is the development ...                  3
#
#     clarity_problem  suitability_solution  clarity_solution
# 0                 1                     3                 1
# 1                 3                     3                 3
# 2                 1                     1                 2
# 3                 3                     3                 3
# 4                 3                     3                 3
# 5                 2                     3                 2
# 6                 2                     3                 3
# 7                 1                     3                 2
# 8                 3                     3                 3
# 9                 3                     3                 3
# 10                3                     2                 3
# 11                1                     1                 1
# 12                1                     1                 1
# 13                2                     3                 3
# 14                3                     3                 3
# 15                2                     3                 3
# 16                2                     2                 3
# 17                1                     3                 3
# 18                2                     3                 3
# 19                1                     2                 3
# 20                1                     2                 1
# 21                2                     3                 3
# 22                3                     3                 3
# 23                3                     3                 3
# 24                3                     3                 3
# 25                2                     3                 3
# 26                1                     1                 1
# 27                3                     3                 3
# 28                3                     3                 3
# 29                3                     3                 2
# 30                3                     3                 3
# 31                2                     2                 2
# 32                3                     3                 3
# 33                1                     1                 1
# 34                3                     1                 3
# 35                2                     1                 3
# 36                3                     3                 3
# 37                3                     3                 3
# 38                1                     2                 1
# 39                3                     3                 3
# 40                3                     3                 3
# 41                3                     3                 3
# 42                3                     3                 3
# 43                3                     1                 3
# 44                3                     3                 3
# 45                3                     3                 3
# 46                3                     1                 3
# 47                1                     3                 3
# 48                1                     1                 2
# 49                3                     3                 2

# %%
# Save labeled train data as json
# json_filepath = '../data/json/test_data_labeled.json'
df_dict = df.to_dict(orient='records')
df_dict
# df_dict = json.load(df_json)

df_dict[0]
# Out:
# {'problem': 'Plastic waste pollution',
#  'solution': 'recycling single-use plastic waste and converting it into interlocking tiles.',
#  'relevance_problem': 3,
#  'clarity_problem': 1,
#  'suitability_solution': 3,
#  'clarity_solution': 1}

# %%
# Separate key-value pairs into two lists of dicts: 
# prompt (problem, solution) and response (relevance_problem, clarity_problem, suitability_solution, clarity_solution
df_dict_prompt = [{k: v for k, v in d.items() if k in ['problem', 'solution']} for d in df_dict]
df_dict_response = [{k: v for k, v in d.items() if k in ['relevance_problem', 'clarity_problem', 'suitability_solution', 'clarity_solution']} for d in df_dict]

# %%
df_dict_prompt[0]
# Out:
# {'problem': 'Plastic waste pollution',
#  'solution': 'recycling single-use plastic waste and converting it into interlocking tiles.'}

# %%
df_dict_response[0]
# Out:
# {'relevance_problem': 3,
#  'clarity_problem': 1,
#  'suitability_solution': 3,
#  'clarity_solution': 1}

# %% [markdown]
# # Format train data into training examples for fine-tuning

# %%
# Define system content
system_content = "You are a venture capital expert evaluating potential circular economy startup pitches. \
Mark the startup idea (problem and solution) \
from 1 to 3 in integer numbers (where 1 is bad, 2 is okay, and 3 is good) \
in each of four criteria: \
relevance of the problem to the circular economy (relevance_problem), \
clarity of the problem (clarity_problem), \
suitability of solution to the problem (suitability_solution) and \
clarity of the solution (clarity_solution). \
Return the following fields in a JSON dict: \
'relevance_problem', 'clarity_problem', 'suitability_solution' and 'clarity_solution'."

# %%
def generate_example(system_content, user_content, assistant_content):
    # Generate prompts  
    system_dict = {"role": "system", "content": system_content} # system prompt
    user_dict = {"role": "user", "content": str(user_content)} # user prompt
    assistant_dict = {"role": "assistant", "content": str(assistant_content)} # assistant prompt

    # Combine to generate training/validation example
    example = {"messages": [system_dict, user_dict, assistant_dict]}

    return example

# %%
# Generate training/validation examples
examples = [generate_example(system_content, user_content, assistant_content) for user_content, assistant_content in zip(df_dict_prompt, df_dict_response)]

# Save as json
examples_filepath = '../data/json/test_examples.jsonl'
with open(examples_filepath, 'w') as f:
    for example in examples:
        json.dump(example, f)
        f.write('\n')

examples[0]
# Out:
# {'messages': [{'role': 'system',
#    'content': "You are a venture capital expert evaluating potential circular economy startup pitches. Mark the startup idea (problem and solution) from 1 to 3 in integer numbers (where 1 is bad, 2 is okay, and 3 is good) in each of four criteria: relevance of the problem to the circular economy (relevance_problem), clarity of the problem (clarity_problem), suitability of solution to the problem (suitability_solution) and clarity of the solution (clarity_solution). Return the following fields in a JSON dict: 'relevance_problem', 'clarity_problem', 'suitability_solution' and 'clarity_solution'."},
#   {'role': 'user',
#    'content': "{'problem': 'Plastic waste pollution', 'solution': 'recycling single-use plastic waste and converting it into interlocking tiles.'}"},
#   {'role': 'assistant',
#    'content': "{'relevance_problem': 3, 'clarity_problem': 1, 'suitability_solution': 3, 'clarity_solution': 1}"}]}
