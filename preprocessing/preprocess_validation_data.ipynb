# %%
from openai import OpenAI
import pandas as pd
import numpy as np
import os
import json

# %% [markdown]
# # Preprocess df

# %%
# Preprocess df
df = pd.read_csv('../data/validation_data_labeled.csv')[['problem', 'solution', 'relevance_problem', 'clarity_problem', 'suitability_solution', 'clarity_solution']]
df
# Out:
#                                               problem  \
# 0                 I want to turn my work into digital
# 1   Traditional fast-fashion businesses operate on...
# 2   The escalating problem of single-use packaging...
# 3   The significant amount of packaging waste gene...
# 4   The modern consumer market suffers from proble...
# 5   The accelerating culture of disposability of e...
# 6   The fast fashion industry generates a large pe...
# 7   Make it more human-centered. Appeal to the emo...
# 8   Everyday business operations, particularly pac...
# 9   Plastic pollution is a big problem in the worl...
# 10  The issue pertains to excessive waste generati...
# 11  Saruchal is made to address the problem of lim...
# 12  The issue is that a substantial amount of wast...
# 13  The textile industry is one of the major contr...
# 14  The high consumption rate and substantial wast...
# 15  Broad-based integration of the circular econom...
# 16  The fast-fashion industry contributes signific...
# 17  Current manufacturing processes are primarily ...
# 18  Our products are meant to support other electr...
# 19  The excessive production and disposal of singl...
# 20  The overconsumption of plastic and textile was...
# 21  Electronic Waste or E-Waste is a rapidly growi...
# 22  For a sustainable future, a new revolution in ...
# 23  The consumption and disposal of single-use pla...
# 24  The rapid evolution and obsolescence of techno...
# 25  Millions of tons of e-waste are generated each...
# 26          Natural cold fresh water bottle reusable.
# 27  The textile industry is one of the world's lea...
# 28  Electronic waste continues to be a significant...
# 29  A significant amount of resources, both in ter...
# 30  Real estate property management often involves...
# 31  The rapid increase of plastic waste has become...
# 32  Recently, BCG commissioned a survey spanning f...
# 33  Mass-produced furniture has a significant effe...
# 34  The construction industry creates a significan...
# 35  Plastic waste to help in conserving agricultur...
# 36  Problem - Ink from Printed Books. Concept- Few...
# 37  Construction and demolition industries generat...
# 38  There is a significant environmental challenge...
# 39  The current fashion economy model generates ex...
# 40  I'm sorry, but I need more information about w...
# 41  Industries that generate waste and cannot and/...
# 42  It is crucial to find a more novel, impactful,...
# 43  260 Million + Stolen delivered packages from p...
# 44  I have an example of creating beautiful dresse...
# 45                  give an elegant look to your home
# 46  The apparel and fashion industry is one of the...
# 47                   Vehicle Greenhouse Gas Emissions
# 48  Many food products are significantly impacted ...
# 49  Inefficient use of plastic resources leads to ...
#
#                                              solution  relevance_problem  \
# 0                     I want everyone to be efficient                  1
# 1   Refashioning the 'Fast Fashion' industry with ...                  3
# 2   The Loop system is a revolutionary circular ec...                  3
# 3   Our proposal is 'Community Hub for Reusable Pa...                  3
# 4   The development of a QR-Code Recycling Informa...                  3
# 5   Drawing on the spiral pattern recurrent in nat...                  3
# 6   We propose an upgraded version of âWardrobe ...                  3
# 7   Simplify your points, and reinforce the motiva...                  1
# 8   An improved circular economy idea to address t...                  3
# 9   Clay Pots can be use to drink tea and coffee. ...                  2
# 10  The ""ReCircle"" platform is designed to addre...                  3
# 11  The solution offered by SARUCHAL is a platform...                  1
# 12  The proposal employs AI in the context of wast...                  3
# 13  The solution is a platform for recyclable fash...                  3
# 14  Introduce a scheme to retrofit older car model...                  3
# 15  My solution utilizes AI to manage industrial e...                  2
# 16  The enhanced solution is a âFashion Swap Dig...                  3
# 17  We can introduce a ""Product as a Service"" (P...                  3
# 18  To help and increase the quality of our compan...                  1
# 19  The 'Insert-Frame Packaging Solution' circumve...                  3
# 20  My proposition is a process to effectively rec...                  3
# 21  The proposed solution is a cross-industry ""E-...                  3
# 22  The industrial region will benefit in the near...                  3
# 23  The solution to this problem is to introduce a...                  3
# 24  We could establish a rental or leasing system ...                  3
# 25  The solution, Electronic Waste Recovery and Re...                  3
# 26  Very cheap as it can be made from seasoned cla...                  1
# 27  Our solution is an innovative application that...                  3
# 28  The solution is establishing Circular Electron...                  3
# 29  Implementing a ""Product as a Service"" (PaaS)...                  3
# 30  Develop an innovative digital platform, ""eLea...                  2
# 31  We propose the transformation of plastic waste...                  3
# 32  Skills Hustle solves the skills gap and turns ...                  1
# 33  Hardwood as a material is durable, high qualit...                  3
# 34  A construction materials marketplace that enab...                  3
# 35  In Africa, many farmers rely on rain water to ...                  3
# 36  The ink residue can leave black marks on your ...                  1
# 37  Advanced Concrete Waste Transformation into Ec...                  3
# 38  ""Green Packaging Partnership"" proposes a com...                  3
# 39  The solution is 'Fashion-as-a-Service' (FaaS),...                  3
# 40  Process of evaluating consumer response to a p...                  1
# 41  Creation of a digital platform that connects c...                  2
# 42  My idea is an innovative platform, ""Scrap-to-...                  3
# 43  An outdoor ""Package Lock Box"" that looks lik...                  1
# 44  I am an artist and I design jewelry, and I als...                  2
# 45  You can use old non-working light bulbs as sou...                  1
# 46  In response to this problem, we propose an inn...                  3
# 47  The solution is to use a water-fuelled car tha...                  3
# 48  Introduce higher levels of antioxidants in foo...                  2
# 49  The 'Plastic as a Service with Technology Inte...                  3
#
#     clarity_problem  suitability_solution  clarity_solution
# 0                 1                     1                 1
# 1                 3                     3                 3
# 2                 3                     3                 3
# 3                 3                     3                 3
# 4                 3                     2                 3
# 5                 3                     3                 3
# 6                 3                     3                 3
# 7                 1                     1                 1
# 8                 3                     3                 3
# 9                 2                     2                 2
# 10                3                     3                 3
# 11                2                     2                 2
# 12                3                     3                 3
# 13                3                     3                 3
# 14                3                     3                 3
# 15                1                     2                 1
# 16                3                     3                 3
# 17                2                     3                 2
# 18                1                     2                 1
# 19                3                     3                 3
# 20                3                     3                 3
# 21                3                     3                 3
# 22                3                     1                 1
# 23                3                     3                 3
# 24                3                     3                 3
# 25                3                     3                 3
# 26                1                     2                 1
# 27                3                     3                 3
# 28                3                     3                 3
# 29                3                     3                 3
# 30                3                     3                 3
# 31                3                     3                 3
# 32                3                     3                 3
# 33                3                     1                 3
# 34                2                     3                 3
# 35                1                     2                 2
# 36                1                     2                 1
# 37                3                     3                 3
# 38                3                     3                 3
# 39                3                     3                 3
# 40                1                     1                 1
# 41                1                     3                 2
# 42                2                     3                 3
# 43                2                     2                 1
# 44                1                     2                 2
# 45                2                     1                 1
# 46                3                     3                 3
# 47                1                     2                 1
# 48                3                     3                 3
# 49                2                     3                 3

# %%
# Save labeled train data as json
json_filepath = '../data/json/validation_data_labeled.json'
df_json = df.to_json(json_filepath, orient='records', indent=4)

# Load json and show as list of dicts
with open(json_filepath) as f:
    df_dict = json.load(f)

df_dict[0]
# Out:
# {'problem': 'I want to turn my work into digital',
#  'solution': 'I want everyone to be efficient',
#  'relevance_problem': 1,
#  'clarity_problem': 1,
#  'suitability_solution': 1,
#  'clarity_solution': 1}

# %%
# Separate key-value pairs into two lists of dicts: 
# prompt (problem, solution) and response (relevance_problem, clarity_problem, suitability_solution, clarity_solution
df_dict_prompt = [{k: v for k, v in d.items() if k in ['problem', 'solution']} for d in df_dict]
df_dict_response = [{k: v for k, v in d.items() if k in ['relevance_problem', 'clarity_problem', 'suitability_solution', 'clarity_solution']} for d in df_dict]

# %%
df_dict_prompt[0]
# Out:
# {'problem': 'I want to turn my work into digital',
#  'solution': 'I want everyone to be efficient'}

# %%
df_dict_response[0]
# Out:
# {'relevance_problem': 1,
#  'clarity_problem': 1,
#  'suitability_solution': 1,
#  'clarity_solution': 1}

# %% [markdown]
# # Format train data into training examples for fine-tuning

# %%
# Define system content
system_content = "You are a venture capital expert evaluating potential circular economy startup pitches. \
Mark the startup idea (problem and solution) \
from 1 to 3 in integer numbers (where 1 is bad, 2 is okay, and 3 is good) \
in each of four criteria: \
relevance of the problem to the circular economy (relevance_problem), \
clarity of the problem (clarity_problem), \
suitability of solution to the problem (suitability_solution) and \
clarity of the solution (clarity_solution). \
Return the following fields in a JSON dict: \
'relevance_problem', 'clarity_problem', 'suitability_solution' and 'clarity_solution'."

# %%
def generate_example(system_content, user_content, assistant_content):
    # Generate prompts  
    system_dict = {"role": "system", "content": system_content} # system prompt
    user_dict = {"role": "user", "content": str(user_content)} # user prompt
    assistant_dict = {"role": "assistant", "content": str(assistant_content)} # assistant prompt

    # Combine to generate training/validation example
    example = {"messages": [system_dict, user_dict, assistant_dict]}

    return example

# %%
# Generate training/validation examples
examples = [generate_example(system_content, user_content, assistant_content) for user_content, assistant_content in zip(df_dict_prompt, df_dict_response)]

# Save as json
examples_filepath = '../data/json/validation_examples.jsonl'
with open(examples_filepath, 'w') as f:
    for example in examples:
        json.dump(example, f)
        f.write('\n')

examples[0]
# Out:
# {'messages': [{'role': 'system',
#    'content': "You are a venture capital expert evaluating potential circular economy startup pitches. Mark the startup idea (problem and solution) from 1 to 3 in integer numbers (where 1 is bad, 2 is okay, and 3 is good) in each of four criteria: relevance of the problem to the circular economy (relevance_problem), clarity of the problem (clarity_problem), suitability of solution to the problem (suitability_solution) and clarity of the solution (clarity_solution). Return the following fields in a JSON dict: 'relevance_problem', 'clarity_problem', 'suitability_solution' and 'clarity_solution'."},
#   {'role': 'user',
#    'content': "{'problem': 'I want to turn my work into digital', 'solution': 'I want everyone to be efficient'}"},
#   {'role': 'assistant',
#    'content': "{'relevance_problem': 1, 'clarity_problem': 1, 'suitability_solution': 1, 'clarity_solution': 1}"}]}
